# %% [markdown]
# <a href="https://colab.research.google.com/github/millicentjohnsonr-cpu/Python-for-AI-And-ML/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
food1 = ["rice", "beans", "oatmeal", "plaintain","noodles", "egg" ]
millicent = food1 [1]
millz = food1 [3]
milly = food1 [0]
print (f"please i need a plate of {millicent},  {millz} and {milly}")
# Out:
# please i need a plate of beans,  plaintain and rice

# %%
mod_food = ["rice", "beans", "oatmeal", "plaintain", "noodles", "egg"]
mod_food [2] = "yam"
print (mod_food)
mod_food.append ("meat")
print (mod_food)
mod_food.insert (4, "chicken")
print (mod_food)
mod_food.remove ("noodles")
print (mod_food)
mod_food.reverse ()
print (mod_food)
mod_food.pop ()
print (mod_food)
# Out:
# ['rice', 'beans', 'yam', 'plaintain', 'noodles', 'egg']
# ['rice', 'beans', 'yam', 'plaintain', 'noodles', 'egg', 'meat']
# ['rice', 'beans', 'yam', 'plaintain', 'chicken', 'noodles', 'egg', 'meat']
# ['rice', 'beans', 'yam', 'plaintain', 'chicken', 'egg', 'meat']
# ['meat', 'egg', 'chicken', 'plaintain', 'yam', 'beans', 'rice']
# ['meat', 'egg', 'chicken', 'plaintain', 'yam', 'beans']
