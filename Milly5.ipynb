# %% [markdown]
# <a href="https://colab.research.google.com/github/millicentjohnsonr-cpu/Python-for-AI-And-ML/blob/main/Milly5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import getpass

Customer_name = input ("Enter username:")
stored_password = getpass.getpass ("create your password:")
entered_password = getpass.getpass ("Enter your password to login:")
Loan_history = False
Standing_capital = int (input ("Enter your standing capital, it should not ne less than 100,000:"))
Email = input ("Enter your email:")
Account_number = int (input ("Enter your account number:"))
Bank_name = input ("Enter your bank name:")
Account_name = input ("Enter your full name:")
Gender = input ("Enter your gender male/female:")
Business_type = input ("Enter ypur business type:")

if entered_password == stored_password:
  print("login successful")
  if Standing_capital >= 100000:
    if Loan_history == False:
      print("Loan approved")
    else:
      print("You are not eligible for a loan")
  else:
    print("Your standing capital is low")
else:
  print("Incorrect password")
# Out:
# Enter username:Micentz
# create your password:··········
# Enter your password to login:··········
# Enter your standing capital, it should not ne less than 100,000:120000
# Enter your email:millz@gmail.com
# Enter your account number:5694786329
# Enter your bank name:Moniepoint
# Enter your full name:Milly Rich Jay
# Enter your gender male/female:Female
# Enter ypur business type:Data Analyst
# login successful
# Loan approved
