# %% [markdown]
# <a href="https://colab.research.google.com/github/millicentjohnsonr-cpu/Python-for-AI-And-ML/blob/main/MillyAssignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Ghana = 45
Nigeria = 66
if not Ghana > Nigeria:
  print ("Ghana is  not greater than Nigeria")
else:
  print ("Ghana is greater than Nigeria")
# Out:
# Ghana is  not greater than Nigeria

# %%
Employee_number = "AS274816"
Password = "Richie14"
is_verified = True

if Employee_number and Password and is_verified:
    print ("Login successful")
    print ("You are welcome back")
else:
    print ("Invalid login details")
# Out:
# Login successful
# You are welcome back

# %%
Customer_name = "Caroline"
Loan_history = "Nil"
is_debtor = True
Standing_capital = 100,000

if Customer_name:
  if Loan_history:
    if is_debtor:
      if Standing_capital:
        print ("You are eligible for a loan")
        print ("Fill in the form below")

      else:
        print ("You do not have the required standing capital")
    else:
      print ("You have an outstanding debt")
  else:
    print ("No loan record")
else:
  print("Customer name does not exist")
# Out:
# You are eligible for a loan
# Fill in the form below
